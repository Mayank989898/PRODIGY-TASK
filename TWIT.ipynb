# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objects as go

# %%
# Load the data
file_path = r"C:\Users\user\Desktop\twit.csv"
df = pd.read_csv(file_path)
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# ...

# %%
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.shape
# Out:
# (74681, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   2401                                                   74681 non-null  int64
#  1   Borderlands                                            74681 non-null  object
#  2   Positive                                               74681 non-null  object
#  3   im getting on borderlands and i will murder you all ,  73995 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df.describe(include=object)
# Out:
#                  Borderlands  Positive  \
# count                  74681     74681
# unique                    32         4
# top     TomClancysRainbowSix  Negative
# freq                    2400     22542
#
#        im getting on borderlands and i will murder you all ,
# count                                               73995
# unique                                              69488
# top     At the same time, despite the fact that there ...
# freq                                                  172

# %%
df['Positive'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %%
df.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#        2401  Borderlands  Positive  \
# 60     2411  Borderlands   Neutral
# 552    2496  Borderlands   Neutral
# 588    2503  Borderlands   Neutral
# 744    2532  Borderlands  Positive
# 1104   2595  Borderlands  Positive
# ...     ...          ...       ...
# 73971  9073       Nvidia  Positive
# 73972  9073       Nvidia  Positive
# 74420  9154       Nvidia  Positive
# 74421  9154       Nvidia  Positive
# 74422  9154       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 60                                                   NaN
# 552                                                  NaN
# 588                                                  NaN
# 744                                                  NaN
# 1104                                                 NaN
# ...                                                  ...
# 73971                                                NaN
# 73972                                                NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 2401                                                     0
# Borderlands                                              0
# Positive                                                 0
# im getting on borderlands and i will murder you all ,    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2341

# %%
df[df.duplicated()]
# Out:
#        2401  Borderlands  Positive  \
# 19     2404  Borderlands  Positive
# 25     2405  Borderlands  Negative
# 50     2409  Borderlands   Neutral
# 63     2411  Borderlands   Neutral
# 145    2425  Borderlands  Negative
# ...     ...          ...       ...
# 74504  9171       Nvidia   Neutral
# 74509  9172       Nvidia  Positive
# 74588  9185       Nvidia   Neutral
# 74618  9190       Nvidia  Positive
# 74635  9193       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 19     that was the first borderlands session in a lo...
# 25     The biggest disappointment of my life came a y...
# 50     Blaming Sight for Tardiness! A little bit of b...
# 63                                                  .. [
# 145                                      "What a bitch!"
# ...                                                  ...
# 74504  This benchmarking comparison between Oculus Qu...
# 74509                           @ NVIDIAGeForce @ nvidia
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#        2401  Borderlands  Positive  \
# 17     2404  Borderlands  Positive
# 19     2404  Borderlands  Positive
# 24     2405  Borderlands  Negative
# 25     2405  Borderlands  Negative
# 47     2409  Borderlands   Neutral
# ...     ...          ...       ...
# 74588  9185       Nvidia   Neutral
# 74615  9190       Nvidia  Positive
# 74618  9190       Nvidia  Positive
# 74634  9193       Nvidia  Positive
# 74635  9193       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 17     that was the first borderlands session in a lo...
# 19     that was the first borderlands session in a lo...
# 24     The biggest disappointment of my life came a y...
# 25     The biggest disappointment of my life came a y...
# 47     Blaming Sight for Tardiness! A little bit of b...
# ...                                                  ...
# 74588  Heard people are having issues with ordering t...
# 74615  This news about the Nvidia 3000 series is ligi...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
df['Borderlands'].value_counts().plot(kind='barh',color='b')
plt.xlabel("Count")
plt.show()

# %%
sns.countplot(x = 'Borderlands',data=df,palette='viridis')
plt.show()

# %%
# Calculate the counts for each Borderlands
Borderlands_counts = df['Borderlands'].value_counts()

# Create the pie chart
plt.figure(figsize=(10, 10))
plt.pie(Borderlands_counts, labels=Borderlands_counts.index, autopct="%1.1f%%", startangle=140, colors=['skyblue', 'orange', 'green', 'red', 'purple'])

plt.title('Borderlands Distribution')

# Show the plot
plt.show()

# %%
df['msg_len'] = df['im getting on borderlands and i will murder you all ,'].apply(len)

# %%
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,  msg_len
# 0      I am coming to the borders and I will kill you...          51
# 1      im getting on borderlands and i will kill you ...          50
# 2      im coming on borderlands and i will murder you...          51
# 3      im getting on borderlands 2 and i will murder ...          57
# 4      im getting into borderlands and i can murder y...          53
# ...                                                  ...         ...
# ...

# %%
sns.histplot(df['msg_len'], bins=25,kde=True)
plt.title('Message Length Distribution in Training Data')
plt.ylabel('Frequency')
plt.xlabel('Message Length')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(data=df, x=df['Positive'], y='msg_len', palette='viridis', order=['Positive', 'Negative', 'Neutral', 'Irrelevant'])
plt.title('Message Length Distribution by Sentiment in Training Data')
plt.ylabel('Message Length')
plt.xlabel('Positive')
plt.ylim(0,300)
plt.show()

# %%
crosstab = pd.crosstab(index=df['Borderlands'], columns=df['Positive'])

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(crosstab, cmap='coolwarm', annot=True, fmt='d', linewidths=.5)

# Add labels and title
plt.title('Heatmap of Borderlands vs Positive')
plt.xlabel('Positive')
plt.ylabel('Borderlands')

# Show the plot
plt.show()
